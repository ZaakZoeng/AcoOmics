# %% [markdown]
# # 06.12_All_process_h5ad_Python
#
# 整合 AnnData 后处理。
#
# - 当前文件：`analysis/06_single_cell_analysis/06.12_All_process_h5ad_Python.ipynb`
# - 原始来源：`Codes/06.11_process_h5ad.ipynb`（旧编号仅用于溯源）。
# - 运行内核：**python**。
# - 导入依赖：`scanpy`。
# - 当前编号与流程见 `docs/workflow.md`、`docs/code_index.md`。
# - 仅更新整理版导读；原分析单元格、参数和顺序保持不变。原始 cell 索引在本文件中加 1。

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('/share/home/zhangze/zz/NeuralOrigin/Data/06.SingleCellAnalysis/SingleCellIntegrated/Seurat_RPCA_to_Scanpy/sc_BasalMetazoa.normalized.h5ad')
adata

# %%
adata.obs.drop(columns=['broad_cell_type', 'CellType', 'annos', 'Sub_cell_type', 'Broad_cell_type', 'CellTypeFamily', 'seurat_clusters', 'integrated_snn_res.0.5', 'species_ordered'], inplace=True)
adata

# %%
sc.pl.umap(adata, color=['species', 'Phylum', 'BroadType'])

# %%
sc.pl.umap(adata, color=['CellTypes'])

# %%
# 压缩保存adata数据
raw_9species_gzip_path = "/share/home/zhangze/zz/NeuralOrigin/Data/06.SingleCellAnalysis/SingleCellIntegrated/Seurat_RPCA_to_Scanpy/sc_BasalMetazoa.normalized.gzip.h5ad"
adata.write(raw_9species_gzip_path, compression="gzip")
